# %%
import os
import sys
sys.path.append(os.path.abspath("../src"))
sys.path.append(os.path.abspath("../lightning_logs"))

# %%
from utils_result import get_loss,get_standardised_loss
from plot import plot_bar_vertical
import pandas as pd

# %%
best_models_dir = "../results/final_models"

# %%
standardised_loss = get_standardised_loss(best_models_dir,"final","predict_loss")
loss = get_loss(best_models_dir,"final","predict_loss")

# %%
plot_bar_vertical(
    data_series=standardised_loss,
    title="",
    xlabel="",
    ylabel="Mean MAD",
    figsize=(10, 6)
)

# %%
plot_bar_vertical(
    data_series=loss,
    title="",
    xlabel="",
    ylabel="Mean MAD",
    figsize=(10, 6)
)
