# %%
import os
import sys
sys.path.append(os.path.abspath("../src"))
sys.path.append(os.path.abspath("../lightning_logs"))

# %%
from utils_result import get_loss,get_standardised_loss
from plot import plot_bar_vertical
import pandas as pd

# %%
best_models_dir = "../final_results/seeds"

# %% [markdown]
# # Test

# %%
standardised_loss = get_standardised_loss(best_models_dir,"","test_loss")
loss = get_loss(best_models_dir,"","test_loss")

# %%
loss
# Out:
# base_1         8.005542
# base_117       7.945697
# base_42        8.031546
# context_1      7.132574
# context_117    7.061072
# context_42     6.820821
# dtype: float64

# %%
standardised_loss
# Out:
# base_1         0.2451
# base_117       0.2460
# base_42        0.2450
# context_1      0.2324
# context_117    0.2318
# context_42     0.2282
# dtype: float64

# %%
plot_bar_vertical(
    data_series=standardised_loss,
    title="",
    xlabel="",
    ylabel="standardised loss",
    figsize=(10, 6)
)

# %%
plot_bar_vertical(
    data_series=loss,
    title="",
    xlabel="",
    ylabel="loss",
    figsize=(10, 6)
)

# %% [markdown]
# # val

# %%
standardised_loss = get_standardised_loss(best_models_dir,"","val_loss")
loss = get_loss(best_models_dir,"","val_loss")

# %%
plot_bar_vertical(
    data_series=standardised_loss,
    title="",
    xlabel="",
    ylabel="standardised loss",
    figsize=(10, 6)
)

# %%
plot_bar_vertical(
    data_series=loss,
    title="",
    xlabel="",
    ylabel="loss",
    figsize=(10, 6)
)
